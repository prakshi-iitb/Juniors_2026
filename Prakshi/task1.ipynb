# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: matplotlib in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 2)) (3.9.4)
# Requirement already satisfied: scikit-learn in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: tensorflow in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 4)) (2.20.0)
# Requirement already satisfied: torch in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 5)) (2.8.0)
# Requirement already satisfied: pillow in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from -r requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from matplotlib->-r requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: scipy>=1.6.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (6.33.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 4)) (58.0.4)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorflow->-r requirements.txt (line 4)) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 4)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 4)) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorflow->-r requirements.txt (line 4)) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow->-r requirements.txt (line 4)) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from tensorboard~=2.20.0->tensorflow->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: filelock in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from torch->-r requirements.txt (line 5)) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from torch->-r requirements.txt (line 5)) (1.14.0)
# Requirement already satisfied: networkx in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from torch->-r requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from torch->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: fsspec in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from torch->-r requirements.txt (line 5)) (2025.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 4)) (0.37.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 2)) (3.23.0)
# Requirement already satisfied: rich in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from keras>=3.10.0->tensorflow->-r requirements.txt (line 4)) (14.3.3)
# Requirement already satisfied: namex in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from keras>=3.10.0->tensorflow->-r requirements.txt (line 4)) (0.1.0)
# Requirement already satisfied: optree in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from keras>=3.10.0->tensorflow->-r requirements.txt (line 4)) (0.19.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard~=2.20.0->tensorflow->-r requirements.txt (line 4)) (8.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.10.0->tensorflow->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from rich->keras>=3.10.0->tensorflow->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow->-r requirements.txt (line 4)) (0.1.2)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

# 1. Generate Synthetic Data
# We are creating 300 points clustered around 4 centers
X, y = make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=18)  #change the random_state to see different clusters and centers to see different elbow plots

# 2. Implement K-Means
# HINT: Initialize the KMeans object with 4 clusters, then 'fit' it to X
# TODO: kmeans = KMeans(n_clusters=...)
kmeans=KMeans(n_clusters=4)
# TODO: kmeans.fit(...)
kmeans.fit(X)

# 3. Get Predictions
# HINT: Use the .predict() method to assign each point to a cluster
# TODO: labels = kmeans.predict(X)
labels=kmeans.predict(X)

# 4. Plotting (Provided)
plt.scatter(X[:, 0], X[:, 1], c=labels, s=10, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5, label='Centroids')
plt.title("K-Means Clustering Result")
plt.legend()
plt.show()

# %%
inertias = []
k_values = range(1, 11)

for k in k_values:
    km = KMeans(n_clusters=k, random_state=0, n_init=10)
    km.fit(X)
    inertias.append(km.inertia_)

plt.figure(figsize=(6, 5))
plt.plot(k_values, inertias, marker='o')
plt.title("Elbow Plot")
plt.xlabel("Number of clusters (k)")
plt.ylabel("Inertia")
plt.xticks(k_values)
plt.grid(True)
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# 1. Define the Architecture
# HINT: Use models.Sequential() to create a stack of layers.
# We want: 
# - An input layer with 16 neurons (ReLU activation)
# - A hidden layer with 8 neurons (ReLU activation)
# - An output layer with 1 neuron (Sigmoid activation for binary classification)

model = models.Sequential([
    layers.Dense(16,activation='relu',input_shape=(2,)),
    layers.Dense(8,activation='relu'),
    layers.Dense(1,activation='sigmoid')
    # TODO: layers.Dense(..., activation='relu', input_shape=(2,)), 
    # TODO: layers.Dense(..., activation='...'), 
    # TODO: layers.Dense(..., activation='...') 
])

# 2. Compile the Model
# HINT: The 'optimizer' is the algorithm that updates weights (like Adam).
# The 'loss' function measures how wrong the model is.
# TODO: model.compile(optimizer='...', 
#               loss='binary_crossentropy', 
#               metrics=['accuracy'])
model.compile(optimizer='adam',
        loss='binary_crossentropy',
        metrics=['accuracy']
              )

# 3. View the Architecture
# This shows how many "parameters" (weights) the model will learn.
model.summary()

print("If you see the model summary above, you've successfully built a Neural Network!")
# Out:
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 16)             │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 193 (772.00 B)
#  Trainable params: 193 (772.00 B)
#  Non-trainable params: 0 (0.00 B)
# If you see the model summary above, you've successfully built a Neural Network!

# %%
import torch
import torch.nn as nn

class ComplexNet(nn.Module):
    def __init__(self, input_dim=2, hidden_dims=(64, 128, 64), output_dim=1):
        super().__init__()
        # HINT: nn.Sequential groups layers together.
        # Use nn.Linear(input, output) for dense layers.
        # Use nn.ReLU() for activation and nn.Dropout(p) for regularization.
        
        self.net = nn.Sequential(
            # Layer 1: Input to 64 neurons
            # TODO: nn.Linear(input_dim, ...),
            nn.Linear(input_dim,hidden_dims[0]),
            nn.BatchNorm1d(hidden_dims[0]),
            nn.ReLU(),
            nn.Dropout(0.2),

            # Layer 2: 64 to 128 neurons
            # TODO: nn.Linear(..., hidden_dims[1]),
            nn.Linear(hidden_dims[0],hidden_dims[1]),
            nn.BatchNorm1d(hidden_dims[1]),
            nn.ReLU(),
            nn.Dropout(0.3),
            # TODO: nn.Dropout(0.3),

            # Layer 3: 128 to 64 neurons
            nn.Linear(hidden_dims[1], hidden_dims[2]),
            nn.ReLU(),

            # Output Layer: 64 to output_dim
            # TODO: nn.Linear(..., ...)
            nn.Linear(hidden_dims[2],output_dim)
        )

    def forward(self, x):
        # HINT: This is where the data 'x' passes through the network
        # TODO: return self....(x)
        return self.net(x)
        pass

# 1. Initialize the model
complex_model = ComplexNet()

# 2. Test with a small batch of data (first 16 points)
# HINT: Data must be converted to a Torch 'float32' Tensor
# TODO: x_batch = torch.tensor(X[:16], dtype=torch.float32)
X = torch.randn(100, 2)
x_batch = torch.tensor(X[:16], dtype=torch.float32)


complex_output = complex_model(x_batch)

# 3. Check the results
print(complex_model)
print("Output shape (should be 16, 1):", complex_output.shape)
# Out:
# ComplexNet(
#   (net): Sequential(
#     (0): Linear(in_features=2, out_features=64, bias=True)
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Linear(in_features=64, out_features=128, bias=True)
#     (5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): Dropout(p=0.3, inplace=False)
#     (8): Linear(in_features=128, out_features=64, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=64, out_features=1, bias=True)
#   )
# )
# Output shape (should be 16, 1): torch.Size([16, 1])
# /var/folders/xp/wnzb1jzs525cy0_7r2254g_h0000gn/T/ipykernel_10366/3225713912.py:49: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x_batch = torch.tensor(X[:16], dtype=torch.float32)

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_circles

# 1. Generate "Landing Zone" Data
X_circles, y_circles = make_circles(n_samples=400, noise=0.1, factor=0.5, random_state=40)

# Task: Convert NumPy arrays to PyTorch Tensors
# HINT: Use torch.tensor() and ensure the type is 'float32'
# TODO: X_tensor = torch.tensor(..., dtype=torch.float32)
# TODO: y_tensor = torch.tensor(y_circles, dtype=torch.float32).unsqueeze(1) # We add a dimension for the loss function
X_tensor = torch.tensor(X_circles, dtype=torch.float32)
y_tensor = torch.tensor(y_circles, dtype=torch.float32).unsqueeze(1)


# 2. Build the Neural Network
class CircleNet(nn.Module):
    def __init__(self):
        super().__init__()
        # HINT: Define a stack of layers: Linear(2->8) -> ReLU -> Linear(8->8) -> ReLU -> Linear(8->1) -> Sigmoid
        self.net = nn.Sequential(
            # TODO: nn.Linear(..., ...),
            nn.Linear(2,8),
            nn.ReLU(),
            # TODO: nn.Linear(8, 8),
            nn.Linear(8,8),
            nn.ReLU(),
            # TODO: nn.Linear(..., 1),
            nn.Linear(8,1),
            nn.Sigmoid() # Squishes output between 0 and 1 (probability)
        )
    def forward(self, x):
        return self.net(x)

torch_model = CircleNet()

# 3. Setup Optimizer and Loss Function
# HINT: Use Adam optimizer and Binary Cross Entropy Loss (BCELoss)
# TODO: optimizer = torch.optim.Adam(torch_model.parameters(), lr=0.03)
optimizer = torch.optim.Adam(torch_model.parameters(), lr=0.03)
# TODO: criterion = nn.BCELoss()
criterion = nn.BCELoss()

# 4. The Training Loop (The "Learning" Part)
epochs = 50
losses = []

print("Training the PyTorch Neural Network...")
for epoch in range(epochs):
    torch_model.train()
    
    # STEP A: Reset the gradients to zero
    # TODO: optimizer.zero_grad()
    optimizer.zero_grad()
    # STEP B: Forward Pass (Predict)
    # TODO: y_pred = torch_model(...)
    y_pred = torch_model(X_tensor)
    # STEP C: Calculate the Error (Loss)
    # TODO: loss = criterion(..., ...)
    loss = criterion(y_pred,y_tensor)
    # STEP D: Backpropagation (Calculate how to change weights)
    # TODO: loss.backward()
    loss.backward()
    # STEP E: Update Weights (Take a step)
    # TODO: optimizer.step()
    optimizer.step() 
    losses.append(loss.item())
    if epoch % 10 == 0:
        print(f"Epoch {epoch}: Loss {loss.item():.4f}")

# 5. Evaluate Accuracy
with torch.no_grad():
    # HINT: If prediction >= 0.5, it's class 1, otherwise 0
    preds = (torch_model(X_tensor) >= 0.5).float()
    accuracy = (preds == y_tensor).float().mean()
    print(f"\nFinal Training Accuracy: {accuracy.item() * 100:.2f}%")

# 6. Visualization (Provided)
# This code will visualize the 'Safe Zone' your model has learned
torch_model.eval()
with torch.no_grad():
    x_min, x_max = X_circles[:, 0].min() - 0.5, X_circles[:, 0].max() + 0.5
    y_min, y_max = X_circles[:, 1].min() - 0.5, X_circles[:, 1].max() + 0.5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 200), np.linspace(y_min, y_max, 200))
    grid = torch.tensor(np.c_[xx.ravel(), yy.ravel()], dtype=torch.float32)
    Z = torch_model(grid).numpy().reshape(xx.shape)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(losses)
plt.title("Error Dropping (Gradient Descent)")
plt.xlabel("Epoch"); plt.ylabel("Loss")

plt.subplot(1, 2, 2)
plt.contourf(xx, yy, Z, alpha=0.4, cmap='RdYlBu')
plt.scatter(X_circles[:, 0], X_circles[:, 1], c=y_circles, cmap='RdYlBu', edgecolors='k')
plt.title("Learned Decision Boundary")
plt.show()
# Out:
# Training the PyTorch Neural Network...
# Epoch 0: Loss 0.7149
# Epoch 10: Loss 0.6581
# Epoch 20: Loss 0.5706
# Epoch 30: Loss 0.3595
# Epoch 40: Loss 0.1225
#
# Final Training Accuracy: 99.00%

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# 1. Load Data (Handwritten digits: each image is 8x8 pixels = 64 dimensions)
digits = load_digits()
X, y = digits.data, digits.target

# 2. Apply PCA (Principal Component Analysis)
# HINT: Initialize PCA with 2 components and use fit_transform()
# TODO: pca = PCA(...)
# TODO: X_pca = pca.fit_transform(X)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)


# 3. Apply t-SNE (t-Distributed Stochastic Neighbor Embedding)
# HINT: t-SNE is better at preserving local clusters. Use 2 components.
# TODO: tsne = TSNE(n_components=2, random_state=42)
# TODO: X_tsne = tsne.fit_transform(X)
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# 4. Plotting the Comparison (Provided)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot PCA
ax1.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='tab10', alpha=0.6)
ax1.set_title("PCA: Linear Reduction (Fast but overlapping)")

# Plot t-SNE
ax2.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='tab10', alpha=0.6)
ax2.set_title("t-SNE: Non-linear Reduction (Better separation!)")

plt.show()
# Out:
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/decomposition/_pca.py:606: RuntimeWarning: divide by zero encountered in matmul
#   C = X.T @ X
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/decomposition/_pca.py:606: RuntimeWarning: overflow encountered in matmul
#   C = X.T @ X
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/decomposition/_pca.py:606: RuntimeWarning: invalid value encountered in matmul
#   C = X.T @ X
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: divide by zero encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: overflow encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/decomposition/_base.py:148: RuntimeWarning: invalid value encountered in matmul
#   X_transformed = X @ self.components_.T
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:335: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:335: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:335: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:336: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:336: RuntimeWarning: overflow encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:336: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = normalizer(A.T @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:340: RuntimeWarning: divide by zero encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:340: RuntimeWarning: overflow encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:340: RuntimeWarning: invalid value encountered in matmul
#   Q, _ = qr_normalizer(A @ Q)
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:533: RuntimeWarning: divide by zero encountered in matmul
#   B = Q.T @ M
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:533: RuntimeWarning: overflow encountered in matmul
#   B = Q.T @ M
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:533: RuntimeWarning: invalid value encountered in matmul
#   B = Q.T @ M
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:547: RuntimeWarning: divide by zero encountered in matmul
#   U = Q @ Uhat
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:547: RuntimeWarning: overflow encountered in matmul
#   U = Q @ Uhat
# /Users/prakshichoudhary/Library/Python/3.9/lib/python/site-packages/sklearn/utils/extmath.py:547: RuntimeWarning: invalid value encountered in matmul
#   U = Q @ Uhat

# %%
fig, axes = plt.subplots(4, 10, figsize=(15, 7))

for i, ax in enumerate(axes.flatten()):
    ax.imshow(digits.images[i], cmap='gray')
    ax.set_title(f"Label: {digits.target[i]}", fontsize=8)
    ax.axis('off')

plt.suptitle("Sample Images from the Load Digits Dataset", fontsize=16, y=1.02)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans, DBSCAN

# 1. Generate "Moon-shaped" data + random noise (Provided)
X, _ = make_moons(n_samples=300, noise=0.05, random_state=42)
np.random.seed(42)
outliers = np.random.uniform(low=-1.5, high=2.5, size=(10, 2))
X = np.vstack([X, outliers]) # Merging the shapes with the noise

# 2. Implement K-Means
# HINT: Try to find 2 clusters. Does it work on curved data?
# TODO: kmeans = KMeans(n_clusters=..., random_state=42)
# TODO: kmeans_labels = kmeans.fit_predict(X)
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels = kmeans.fit_predict(X)


# 3. Implement DBSCAN (Density-Based Spatial Clustering)
# HINT: This looks for "dense" areas. 
# Set eps (radius) to 0.2 and min_samples (minimum points to form a group) to 5.
# TODO: dbscan = DBSCAN(eps=..., min_samples=...)
# TODO: dbscan_labels = dbscan.fit_predict(X)
dbscan = DBSCAN(eps=0.2, min_samples=5)
dbscan_labels = dbscan.fit_predict(X)


# 4. Plotting the Comparison
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

# Plot K-Means Results
ax1.scatter(X[:, 0], X[:, 1], c=kmeans_labels, cmap='viridis')
ax1.set_title("K-Means: Tries to find 'Circles'")

# Plot DBSCAN Results
# HINT: DBSCAN labels noise as -1. We color them black.
colors = ['black' if label == -1 else plt.cm.tab10(label) for label in dbscan_labels]
ax2.scatter(X[:, 0], X[:, 1], c=colors)
ax2.set_title("DBSCAN: Finds 'Density' & Identifies Noise (Black)")

plt.show()
